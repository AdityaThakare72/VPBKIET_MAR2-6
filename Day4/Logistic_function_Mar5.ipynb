# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-5, 5, 0.25)
x
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,
#         1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,
#         4.  ,  4.25,  4.5 ,  4.75])

# %%
y = 3.2 * x + 45

# %%
y
# Out:
# array([29. , 29.8, 30.6, 31.4, 32.2, 33. , 33.8, 34.6, 35.4, 36.2, 37. ,
#        37.8, 38.6, 39.4, 40.2, 41. , 41.8, 42.6, 43.4, 44.2, 45. , 45.8,
#        46.6, 47.4, 48.2, 49. , 49.8, 50.6, 51.4, 52.2, 53. , 53.8, 54.6,
#        55.4, 56.2, 57. , 57.8, 58.6, 59.4, 60.2])

# %%
plt.plot(x, y);

# %%
# logistic curve

# %%
def sigmoid(z):
    val = 1 / (1 + np.exp(-z))
    return val

# %%
sigmoid(7)
# Out:
# np.float64(0.9990889488055994)

# %%
plt.plot(x, sigmoid(x));
